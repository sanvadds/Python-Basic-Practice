# %% [markdown]
# <a href="https://colab.research.google.com/github/sanvadds/Python-Basic-Practice/blob/main/Merge_in_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data1 = pd.read_excel("/content/sample_data/employe_id_name.xlsx")
data2 = pd.read_excel("/content/sample_data/employee_id_age.xlsx")

# %%
data1.head()
# Out:
#    ID     Name
# 0   1   Sanvad
# 1   2  Pranali
# 2   3  Riddham
# 3   4   Rigved
# 4   5    Varad

# %%
data2.head()
# Out:
#    ID  Age
# 0   1   30
# 1   2   27
# 2   3    3
# 3   4    6
# 4   5   31

# %%
result_data = pd.merge(data1,data2,on='ID')

# %%
result_data
# Out:
#    ID     Name  Age
# 0   1   Sanvad   30
# 1   2  Pranali   27
# 2   3  Riddham    3
# 3   4   Rigved    6
# 4   5    Varad   31
# 5   6    Omkar   29
# 6   7  Rishabh    2
# 7   8     Ravi   55
# 8   9      Sam   78
# 9  10     John   15
